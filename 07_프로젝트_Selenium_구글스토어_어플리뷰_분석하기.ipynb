# %% [markdown]
# # 1. Selenium 구글스토어 어플 리뷰 분석하기

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys


# Chrome 창 켜기
driver = webdriver.Chrome()
driver.maximize_window()


# URL로 이동45
url = "https://play.google.com/store/apps/details?id=kr.co.yogiyo.owner&hl=ko"
driver.get(url)


# 평점 및 리뷰 더보기 클릭
more_btn_css = "#yDmH0d > c-wiz.SSPGKf.Czez9d > div > div > div:nth-child(1) > div > div.wkMJlb.YWi3ub > div > div.qZmL0 > div:nth-child(1) > c-wiz:nth-child(5) > section > header > div > div:nth-child(2) > button > i"
more_btn = driver.find_element(By.CSS_SELECTOR, more_btn_css)
more_btn.click()


time.sleep(2)

# 스크롤 내리기
rep = 200
display_box_css = "#yDmH0d > div.VfPpkd-Sx9Kwc.cC1eCc.UDxLd.PzCPDd.HQdjr.VfPpkd-Sx9Kwc-OWXEXe-FNFY6c > div.VfPpkd-wzTsW > div > div > div > div > div.fysCi.Vk3ZVd"
display_box = driver.find_element(By.CSS_SELECTOR, display_box_css)
for i in range(rep):
    display_box.send_keys(Keys.END)



# 스크롤 맨 위로 움직이기
display_box.send_keys(Keys.HOME)


# 리뷰 추출하기
review_css = "#yDmH0d > div.VfPpkd-Sx9Kwc.cC1eCc.UDxLd.PzCPDd.HQdjr.VfPpkd-Sx9Kwc-OWXEXe-FNFY6c > div.VfPpkd-wzTsW > div > div > div > div > div.fysCi.Vk3ZVd > div > div:nth-child(2) > div"
reviews = driver.find_elements(By.CSS_SELECTOR, review_css)
reviews


# 모든 리뷰 수집하기
data_list = []
# 10개정도 수집되었을 때 프린트하기
review_count = len(reviews)
for i, review in enumerate(reviews):

    customer_id = review.find_element(By.CLASS_NAME,'X5PpBb').text
    star = review.find_element(By.CLASS_NAME, "iXRFPc").get_attribute("aria-label")
    enroll_date = review.find_element(By.CLASS_NAME, "bp9Aid").text
    content = review.find_element(By.CLASS_NAME, "h3YV2d").text

    review_dict = {
        "customer_id": customer_id,
        "star": star,
        "enroll_date" : enroll_date,
        "content" : content
    }
    # print(review_dict)
    if i % 10 == 0:
        print(f"{review_count}개 중에 {i}번째 리뷰를 수집 중입니다 ....")

    data_list.append(review_dict)


# 데이터프레임 만들기
import pandas as pd
data = pd.DataFrame(data = data_list)


# 데이터프레임 별점에 대한 전처리
data["star"] = data["star"].apply(lambda x: int(x[10]))


# 데이터프레임 날짜 데이터타입 변경
data["enroll_date"] = data["enroll_date"].apply(lambda x: pd.to_datetime(x, format="%Y년 %m월 %d일"))


# csv파일로 저장하기
data.to_csv("07_data/구글플레이스토어_요기요(사장님)_리뷰.csv")
# Out:
# 720개 중에 0번째 리뷰를 수집 중입니다 ....
# 720개 중에 10번째 리뷰를 수집 중입니다 ....
# 720개 중에 20번째 리뷰를 수집 중입니다 ....
# 720개 중에 30번째 리뷰를 수집 중입니다 ....
# 720개 중에 40번째 리뷰를 수집 중입니다 ....
# 720개 중에 50번째 리뷰를 수집 중입니다 ....
# 720개 중에 60번째 리뷰를 수집 중입니다 ....
# 720개 중에 70번째 리뷰를 수집 중입니다 ....
# 720개 중에 80번째 리뷰를 수집 중입니다 ....
# 720개 중에 90번째 리뷰를 수집 중입니다 ....
# 720개 중에 100번째 리뷰를 수집 중입니다 ....
# 720개 중에 110번째 리뷰를 수집 중입니다 ....
# 720개 중에 120번째 리뷰를 수집 중입니다 ....
# 720개 중에 130번째 리뷰를 수집 중입니다 ....
# 720개 중에 140번째 리뷰를 수집 중입니다 ....
# 720개 중에 150번째 리뷰를 수집 중입니다 ....
# 720개 중에 160번째 리뷰를 수집 중입니다 ....
# 720개 중에 170번째 리뷰를 수집 중입니다 ....
# 720개 중에 180번째 리뷰를 수집 중입니다 ....
# 720개 중에 190번째 리뷰를 수집 중입니다 ....
# 720개 중에 200번째 리뷰를 수집 중입니다 ....
# 720개 중에 210번째 리뷰를 수집 중입니다 ....
# 720개 중에 220번째 리뷰를 수집 중입니다 ....
# 720개 중에 230번째 리뷰를 수집 중입니다 ....
# 720개 중에 240번째 리뷰를 수집 중입니다 ....
# 720개 중에 250번째 리뷰를 수집 중입니다 ....
# 720개 중에 260번째 리뷰를 수집 중입니다 ....
# 720개 중에 270번째 리뷰를 수집 중입니다 ....
# 720개 중에 280번째 리뷰를 수집 중입니다 ....
# 720개 중에 290번째 리뷰를 수집 중입니다 ....
# 720개 중에 300번째 리뷰를 수집 중입니다 ....
# 720개 중에 310번째 리뷰를 수집 중입니다 ....
# 720개 중에 320번째 리뷰를 수집 중입니다 ....
# 720개 중에 330번째 리뷰를 수집 중입니다 ....
# 720개 중에 340번째 리뷰를 수집 중입니다 ....
# 720개 중에 350번째 리뷰를 수집 중입니다 ....
# 720개 중에 360번째 리뷰를 수집 중입니다 ....
# 720개 중에 370번째 리뷰를 수집 중입니다 ....
# 720개 중에 380번째 리뷰를 수집 중입니다 ....
# 720개 중에 390번째 리뷰를 수집 중입니다 ....
# 720개 중에 400번째 리뷰를 수집 중입니다 ....
# 720개 중에 410번째 리뷰를 수집 중입니다 ....
# 720개 중에 420번째 리뷰를 수집 중입니다 ....
# 720개 중에 430번째 리뷰를 수집 중입니다 ....
# 720개 중에 440번째 리뷰를 수집 중입니다 ....
# 720개 중에 450번째 리뷰를 수집 중입니다 ....
# 720개 중에 460번째 리뷰를 수집 중입니다 ....
# 720개 중에 470번째 리뷰를 수집 중입니다 ....
# 720개 중에 480번째 리뷰를 수집 중입니다 ....
# 720개 중에 490번째 리뷰를 수집 중입니다 ....
# 720개 중에 500번째 리뷰를 수집 중입니다 ....
# 720개 중에 510번째 리뷰를 수집 중입니다 ....
# 720개 중에 520번째 리뷰를 수집 중입니다 ....
# 720개 중에 530번째 리뷰를 수집 중입니다 ....
# 720개 중에 540번째 리뷰를 수집 중입니다 ....
# 720개 중에 550번째 리뷰를 수집 중입니다 ....
# 720개 중에 560번째 리뷰를 수집 중입니다 ....
# 720개 중에 570번째 리뷰를 수집 중입니다 ....
# 720개 중에 580번째 리뷰를 수집 중입니다 ....
# 720개 중에 590번째 리뷰를 수집 중입니다 ....
# 720개 중에 600번째 리뷰를 수집 중입니다 ....
# 720개 중에 610번째 리뷰를 수집 중입니다 ....
# 720개 중에 620번째 리뷰를 수집 중입니다 ....
# 720개 중에 630번째 리뷰를 수집 중입니다 ....
# 720개 중에 640번째 리뷰를 수집 중입니다 ....
# 720개 중에 650번째 리뷰를 수집 중입니다 ....
# 720개 중에 660번째 리뷰를 수집 중입니다 ....
# 720개 중에 670번째 리뷰를 수집 중입니다 ....
# 720개 중에 680번째 리뷰를 수집 중입니다 ....
# 720개 중에 690번째 리뷰를 수집 중입니다 ....
# 720개 중에 700번째 리뷰를 수집 중입니다 ....
# 720개 중에 710번째 리뷰를 수집 중입니다 ....
